# %%
from distutils.command.install import value

'''演示张量和numpy之间如何相互转换，以及如何从张量标量中提取内容
涉及到的API：
    场景1： 张量->numpy nd数组对象
        张量对象.numpy（）    共享内存
        张量对象.numpy().copy()   不共享内存，链式编程写法
    场景2： numpy nd 数组-> 张量.
        from_numpy()        共享内存
        torch.tensor(nd数组)    不共享内存
    场景3： 从标量张量中 提取其内容.
        标量张量.item()
        numpy->张量：  torch.tensor(nd数组)
        从标量张量中 提取其内容：标量张量.item()
掌握：
    张量->numpy：  张量对象.detach().numpy()
'''
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 from distutils.command.install import value
#       3 '''演示张量和numpy之间如何相互转换，以及如何从张量标量中提取内容
#       4 涉及到的API：
#       5     场景1： 张量->numpy nd数组对象
#    (...)
#      16     张量->numpy：  张量对象.detach().numpy()
#      17 '''
#
# ImportError: cannot import name 'value' from 'distutils.command.install' (C:\Users\FOH\PycharmProjects\.venv\lib\site-packages\setuptools\_distutils\command\install.py)

# %%
import torch
import numpy as np
# 1. 定义函数，演示  张量->numpy
def dm01():
   # 1.创建张量
   t1 = torch.tensor([1, 2, 3, 4, 5])
   print(f't1:{t1},type:{type(t1)}')
   # 2. 张量 ->numpy
   n1=t1.numpy()    # 共享内存
   n1=t1.numpy().copy()  #不共享内存
   print(f'n1:{n1},type:{type(n1)}')
   # 3. 演示上述方式，共享内存。
   n1[0]=100
   print(f'n1:{n1},type:{type(n1)}') # [100,2,3,4,5]
   print(f't1:{t1},type:{type(t1)}') # [100,2,3,4,5]

# %%
# 2. 定义函数，演示  numpy->张量
def dm02():
    # 1. 创建numpy数组
    n1=np.array([11, 22, 33])
    print(f'n1:{n1},type:{type(n1)}')
    # 2.把上述的numpy数组，转换成张量
    # t1=torch.from_numpy(n1).type(torch.float32)  #转换+转类型
    t1=torch.from_numpy(n1)
    print(f't1:{t1},type:{type(t1)}')
    t2=torch.tensor(n1)  # 不共享内存
    print(f't2:{t2},type:{type(t2)}')
       # 3. 演示上述方式，共享内存。
    n1[0]=100
    print(f'n1:{n1}')
    print(f't1:{t1}')
    print(f't2:{t2}')

# %%
# 3. 定义函数，演示  从标量张量(只有一个值的张量)中提取其内容
def dm03():
    # 1. 创建张量
    t1= torch.tensor(100)
    print(f't1:{t1},type:{type(t1)}')
    # 2.从张量中提取内容
    a=t1.item()
    print(f'value:{a},type:{type(a)}')

# %%
# 4. 测试
if __name__ == '__main__':
    # dm01()
    # dm02()
    dm03()
# Out:
# t1:100,type:<class 'torch.Tensor'>
# value:100,type:<class 'int'>
